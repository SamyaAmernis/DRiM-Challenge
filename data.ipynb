# %% [markdown]
# ***Importation of libraries***

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ***Importation of data***

# %%
dfcreation = pd.read_csv(filepath_or_buffer = './TABLE_CREATION_2017_2023.csv')

# %%
dfcreation.head(10)
# Out:
#                                              Secteur  trimestre  code_region  \
# 0  Activites de services administratifs et de sou...      12017            1
# 1  Activites de services administratifs et de sou...      12017            2
# 2  Activites de services administratifs et de sou...      12017            3
# 3  Activites de services administratifs et de sou...      12017            4
# 4  Activites de services administratifs et de sou...      12017            6
# 5  Activites de services administratifs et de sou...      12017           11
# 6  Activites de services administratifs et de sou...      12017           11
# 7  Activites de services administratifs et de sou...      12017           11
# 8  Activites de services administratifs et de sou...      12017           11
# 9  Activites de services administratifs et de sou...      12017           11
#
#   code_dep  nombre_creation
# 0      971              279
# 1      972              638
# 2      973               31
# ...

# %%
dfcreation.tail(15)
# Out:
#                          Secteur  trimestre  code_region code_dep  \
# 43558  Transports et entreposage      42022           84      038
# 43559  Transports et entreposage      42022           84      042
# 43560  Transports et entreposage      42022           84      043
# 43561  Transports et entreposage      42022           84      063
# 43562  Transports et entreposage      42022           84      069
# 43563  Transports et entreposage      42022           84      073
# 43564  Transports et entreposage      42022           84      074
# 43565  Transports et entreposage      42022           93      004
# 43566  Transports et entreposage      42022           93      005
# 43567  Transports et entreposage      42022           93      006
# 43568  Transports et entreposage      42022           93      013
# 43569  Transports et entreposage      42022           93      083
# 43570  Transports et entreposage      42022           93      084
# ...

# %%
dfcreation.shape
# Out:
# (43573, 5)

# %%
dfcreation.columns
# Out:
# Index(['Secteur', 'trimestre', 'code_region', 'code_dep', 'nombre_creation'], dtype='object')

# %%
dfcreation.dtypes
# Out:
# Secteur            object
# trimestre           int64
# code_region         int64
# code_dep           object
# nombre_creation     int64
# dtype: object

# %%
dfcreation.groupby('trimestre').sum()
# Out:
#                                                      Secteur  code_region  \
# trimestre
# 12017      Activites de services administratifs et de sou...        88656
# 12018      Activites de services administratifs et de sou...        87777
# 12019      Activites de services administratifs et de sou...        87939
# 12020      Activites de services administratifs et de sou...        87692
# 12021      Activites de services administratifs et de sou...        89932
# 12022      Activites de services administratifs et de sou...        88898
# 12023      Activites de services administratifs et de sou...        89429
# 22017      Activites de services administratifs et de sou...        87649
# 22018      Activites de services administratifs et de sou...        87056
# 22019      Activites de services administratifs et de sou...        87867
# 22020      Activites de services administratifs et de sou...        86327
# ...

# %%
dfdefaut = pd.read_csv(filepath_or_buffer = './TABLE_DEFAUT_2017_2023.csv')

# %%
dfdefaut.head(5)
dfdefaut.tail(5)
dfdefaut.shape
len(dfdefaut.index)
len(dfdefaut.columns)
dfdefaut.columns
dfdefaut.dtypes
# Out:
# Secteur           object
# trimestre          int64
# code_region      float64
# code_dep          object
# nombre_defaut      int64
# dtype: object

# %%
seriesmacro_xlsx = 'Series macroeconomiques.xlsx'
dfseriesmacro = pd.read_excel(seriesmacro_xlsx)
dfseriesmacro.head()
# Out:
#   Estimations de taux de chômage localisé : comparaisons régionales   \
# 0                                              (en%)
# 1                                                NaN
# 2                                               Code
# 3                                                 00
# 4                                                 00
#
#               Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                    NaN        NaN        NaN        NaN        NaN
# 1                    NaN        NaN        NaN        NaN        NaN
# 2                Libellé    T1_2012    T2_2012    T3_2012    T4_2012
# 3  FRANCE (HORS MAYOTTE)        NaN        NaN        NaN        NaN
# 4  FRANCE METROPOLITAINE        9.1        9.4        9.4        9.8
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 38 Unnamed: 39  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# ...

# %%
catastrophes_xlsx = 'catastrophes_naturelles .xlsx'
dfcatastrophes = pd.read_excel(catastrophes_xlsx)
dfcatastrophes.head()
# Out:
#    codgeo      LIBCOM      GFP Fiscalité Type de groupement Fiscalité  \
# 0  097101  LES ABYMES  CA CAP Excellence                           CA
# 1  097101  LES ABYMES  CA CAP Excellence                           CA
# 2  097101  LES ABYMES  CA CAP Excellence                           CA
# 3  097101  LES ABYMES  CA CAP Excellence                           CA
# 4  097101  LES ABYMES  CA CAP Excellence                           CA
#
#   Code DEP Libellé Département  Code Région Libellé Région  Code Postal  \
# 0      971          GUADELOUPE            1     GUADELOUPE        97139
# 1      971          GUADELOUPE            1     GUADELOUPE        97139
# 2      971          GUADELOUPE            1     GUADELOUPE        97139
# 3      971          GUADELOUPE            1     GUADELOUPE        97139
# 4      971          GUADELOUPE            1     GUADELOUPE        97139
#
#    PoPCommunes2022              typ_catnat  nb_catnat  annees  ppr_prescrit  \
# ...

# %% [markdown]
# ***Data manipulation***

# %% [markdown]
# ***Evolution du nombre d'entreprises créées au cours du temps***

# %%
trimestre_creation = dfcreation.groupby('trimestre')['nombre_creation'].sum()
trimestre_creation = trimestre_creation.reset_index()
trimestre_creation['trimestre'] = trimestre_creation['trimestre'].astype(str)

# %%
trimestre_creation['mois'] = trimestre_creation['trimestre'].str.slice(0, 1).astype(int).map({1: 1, 2: 4, 3: 7, 4: 10})
trimestre_creation['annee'] = trimestre_creation['trimestre'].str.slice(1).astype(int)
trimestre_creation['Date'] = pd.to_datetime(trimestre_creation['annee'].astype(str) + trimestre_creation['mois'].astype(str), format='%Y%m')
trimestre_creation = trimestre_creation.sort_values('Date')
trimestre_creation
# Out:
#    trimestre  nombre_creation  mois  annee       Date
# 0      12017           219492     1   2017 2017-01-01
# 7      22017           187732     4   2017 2017-04-01
# 14     32017           185023     7   2017 2017-07-01
# 20     42017           202223    10   2017 2017-10-01
# 1      12018           239575     1   2018 2018-01-01
# 8      22018           212992     4   2018 2018-04-01
# 15     32018           206688     7   2018 2018-07-01
# 21     42018           225586    10   2018 2018-10-01
# 2      12019           278058     1   2019 2019-01-01
# 9      22019           240754     4   2019 2019-04-01
# 16     32019           244238     7   2019 2019-07-01
# 22     42019           266917    10   2019 2019-10-01
# 3      12020           270841     1   2020 2020-01-01
# 10     22020           197653     4   2020 2020-04-01
# 17     32020           291973     7   2020 2020-07-01
# 23     42020           304734    10   2020 2020-10-01
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(trimestre_creation['Date'], trimestre_creation['nombre_creation'], marker='o', linestyle='-')
plt.title("Évolution des créations d'entreprises par trimestre")
plt.xlabel("Trimestre")
plt.ylabel("Nombre de créations d'entreprises")
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ***Evolution du nombre d'entreprises défaillantes au cours du temps***

# %%
trimestre_defaut = dfdefaut.groupby('trimestre')['nombre_defaut'].sum()
trimestre_defaut = trimestre_defaut.reset_index()
trimestre_defaut['trimestre'] = trimestre_defaut['trimestre'].astype(str)
trimestre_defaut['mois'] = trimestre_defaut['trimestre'].str.slice(0, 1).astype(int).map({1: 1, 2: 4, 3: 7, 4: 10})
trimestre_defaut['annee'] = trimestre_defaut['trimestre'].str.slice(1).astype(int)
trimestre_defaut['Date'] = pd.to_datetime(trimestre_defaut['annee'].astype(str) + trimestre_defaut['mois'].astype(str), format='%Y%m')
trimestre_defaut = trimestre_defaut.sort_values('Date')
trimestre_defaut
# Out:
#    trimestre  nombre_defaut  mois  annee       Date
# 0      12017          14903     1   2017 2017-01-01
# 7      22017          12891     4   2017 2017-04-01
# 14     32017          10215     7   2017 2017-07-01
# 20     42017          13152    10   2017 2017-10-01
# 1      12018          12955     1   2018 2018-01-01
# 8      22018          11861     4   2018 2018-04-01
# 15     32018           9872     7   2018 2018-07-01
# 21     42018          12747    10   2018 2018-10-01
# 2      12019          12641     1   2019 2019-01-01
# 9      22019          11249     4   2019 2019-04-01
# 16     32019           9365     7   2019 2019-07-01
# 22     42019          12156    10   2019 2019-10-01
# 3      12020           9267     1   2020 2020-01-01
# 10     22020           5330     4   2020 2020-04-01
# 17     32020           6214     7   2020 2020-07-01
# 23     42020           7145    10   2020 2020-10-01
# 4      12021           6750     1   2021 2021-01-01
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(trimestre_defaut['Date'], trimestre_defaut['nombre_defaut'], marker='o', linestyle='-')
plt.title("Évolution de defaut d'entreprises par trimestre")
plt.xlabel("Trimestre")
plt.ylabel("Nombre de defauts d'entreprises")
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.plot(trimestre_creation['Date'], trimestre_creation['nombre_creation'], label="Nombre de créations d'entreprises", marker='o', linestyle='-')
ax.plot(trimestre_defaut['Date'], trimestre_defaut['nombre_defaut'], label="Nombre de défauts d'entreprises", marker='s', linestyle='--')

# Ajoutez des étiquettes d'axe et une légende
ax.set_xlabel('Trimestre')
ax.set_ylabel('Créations et défauts')
ax.legend()

# Affichez le graphique
plt.grid(True)
plt.show()
